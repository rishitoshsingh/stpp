# %%
# Import necessary libraries
import sys, os
import numpy as np
import pickle
import tensorflow as tf
import multiprocessing
import glob
from tqdm import tqdm
from waymo_open_dataset.protos import scenario_pb2
from waymo_types import object_type, lane_type, road_line_type, road_edge_type, signal_state, polyline_type

# Define the path to the dataset
dataset_path = '/scratch/rksing18/datasets/waymo/scenario/training'  # Replace with your dataset path
dataset_path = '/scratch/rksing18/datasets/waymo/scenario/testing'  # Replace with your dataset path
src_files = glob.glob(os.path.join(dataset_path, '*.tfrecord*'))
src_files.sort()


print(f"Found {len(src_files)} TFRecord files.")

# Function to parse a single TFRecord file
def parse_tfrecord(record):
    scenario = scenario_pb2.Scenario()
    scenario.ParseFromString(record.numpy())  # Deserialize the TFRecord string to a Scenario object
    return scenario.SerializeToString()  # Serialize the Scenario object to a string

# Wrapper function for tf.py_function
def parse_tfrecord_wrapper(record):
    serialized_scenario = tf.py_function(
        func=parse_tfrecord,
        inp=[record],
        Tout=tf.string  # Output is a serialized string
    )
    return serialized_scenario

# Create a TensorFlow dataset from the TFRecord files
raw_dataset = tf.data.TFRecordDataset(src_files, compression_type="")

# Parse the dataset using the wrapper
parsed_dataset = raw_dataset.map(parse_tfrecord_wrapper)

# Iterate through the dataset and print some information
for i, serialized_scenario in enumerate(parsed_dataset):
    scenario = scenario_pb2.Scenario()
    scenario.ParseFromString(serialized_scenario.numpy())  # Deserialize the string back to a Scenario object
    print(f"Scenario {i}: ID = {scenario.scenario_id}")
    if i == 5:  # Limit to 5 scenarios for demonstration
        break
# Out:
# Found 143 TFRecord files.
# Scenario 0: ID = 53efd22f9e0bd276
# Scenario 1: ID = 4b1f67e58e15e78c
# Scenario 2: ID = 81cb7891dfe69679
# Scenario 3: ID = 3e4bd1a8eab0cab7
# Scenario 4: ID = 339f19cf983ffa68
# Scenario 5: ID = 452c20d8f0e303cb

# %%
def decode_tracks_from_proto(tracks, tracks_to_predict):
    tracks_to_predict_ids = [x.track_index for x in tracks_to_predict]
    print(f"Tracks to predict: {tracks_to_predict_ids}")
    data = None
    for cur_data in tracks:
        cur_traj = [np.array([
            -1.0, -1.0, -1.0, -1.0,
            x.velocity_x, x.velocity_y,
            x.width, x.length, x.height,
            x.center_x, x.center_y, x.center_z,
            x.heading, 1.0 if cur_data.id in tracks_to_predict_ids else 0.0
        ], dtype=np.float32) for x in cur_data.states if x.valid]
        try:
            cur_traj = np.stack(cur_traj, axis=0)  # (num_timestamps, 10)
        except:
            print(f"Skipping {cur_data.id} as it has no valid states.")
            continue
        _data = np.hstack(( np.arange(1, cur_traj.shape[0] + 1, dtype=np.float32).reshape(-1, 1), 
                           np.full((cur_traj.shape[0], 1), cur_data.id, dtype=np.float32),
                           np.array([object_type.get(cur_data.object_type)]*cur_traj.shape[0]).reshape(-1,1), 
                           cur_traj))
        if data is None:
            data = _data
        else:
            data = np.vstack((data, _data))
    data = data[np.lexsort((data[:, 1].astype(float), data[:, 0].astype(float)))]
    return data

# %%
i=0
serialized_scenario = next(iter(parsed_dataset))
scenario = scenario_pb2.Scenario()
scenario.ParseFromString(serialized_scenario.numpy())  # Deserialize the string back to a Scenario object
print(f"\n=== Scenario {i}: ID = {scenario.scenario_id} ===")
try:
    track_infos = decode_tracks_from_proto(scenario.tracks, scenario.tracks_to_predict)
except:
    print("Error decoding tracks.")
    print(f"Scenario ID: {scenario.scenario_id}")
    print(scenario)
# Out:
# === Scenario 0: ID = 53efd22f9e0bd276 ===
# Tracks to predict: [15, 8, 18]
# []
# Skipping 294 as it has no valid states.
# Error decoding tracks.
# Scenario ID: 53efd22f9e0bd276
# timestamps_seconds: 0.0
# timestamps_seconds: 0.09956
# timestamps_seconds: 0.1991
# timestamps_seconds: 0.29862
# timestamps_seconds: 0.39811
# timestamps_seconds: 0.49753
# timestamps_seconds: 0.59696
# timestamps_seconds: 0.69635
# timestamps_seconds: 0.7957
# timestamps_seconds: 0.89505
# timestamps_seconds: 0.99435
# tracks {
#   id: 259
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 316.8645935058594
#     center_y: 7953.30615234375
#     center_z: 121.39199676987984
#     length: 12.407690048217773
#     width: 3.0261433124542236
#     height: 3.3666744232177734
#     heading: 1.554057240486145
#     velocity_x: -0.0439453125
#     velocity_y: -0.72265625
#     valid: true
#   }
#   states {
#     center_x: 316.8626708984375
#     center_y: 7952.96142578125
#     center_z: 121.43236809897911
#     length: 11.541391372680664
#     width: 3.012834310531616
#     height: 3.3573591709136963
#     heading: 1.5601264238357544
#     velocity_x: -0.01922607421875
#     velocity_y: -3.447265625
#     valid: true
#   }
#   states {
#     center_x: 316.8783874511719
#     center_y: 7952.57177734375
#     center_z: 121.44808088713962
#     length: 10.41860580444336
#     width: 2.9327492713928223
#     height: 3.3965189456939697
#     heading: 1.5647579431533813
#     velocity_x: 0.15716552734375
#     velocity_y: -3.896484375
#     valid: true
#   }
#   states {
#     center_x: 316.8745422363281
#     center_y: 7952.5361328125
#     center_z: 121.44967200368646
#     length: 10.214057922363281
#     width: 2.9137399196624756
#     height: 3.392214059829712
#     heading: 1.566989779472351
#     velocity_x: -0.0384521484375
#     velocity_y: -0.3564453125
#     valid: true
#   }
#   states {
#     center_x: 316.8670349121094
#     center_y: 7952.4951171875
#     center_z: 121.46177444995372
#     length: 10.007645606994629
#     width: 2.8954246044158936
#     height: 3.3308560848236084
#     heading: 1.569770097732544
#     velocity_x: -0.0750732421875
#     velocity_y: -0.41015625
#     valid: true
#   }
#   states {
#     center_x: 316.866455078125
#     center_y: 7952.49560546875
#     center_z: 121.47263535172365
#     length: 9.771669387817383
#     width: 2.8954362869262695
#     height: 3.348181962966919
#     heading: 1.5717166662216187
#     velocity_x: -0.00579833984375
#     velocity_y: 0.0048828125
#     valid: true
#   }
#   states {
#     center_x: 316.8697509765625
#     center_y: 7952.53955078125
#     center_z: 121.47532835802254
#     length: 9.574150085449219
#     width: 2.9028537273406982
#     height: 3.349397659301758
#     heading: 1.5731357336044312
#     velocity_x: 0.032958984375
#     velocity_y: 0.439453125
#     valid: true
#   }
#   states {
#     center_x: 316.8658447265625
#     center_y: 7952.57666015625
#     center_z: 121.45874798702732
#     length: 9.432716369628906
#     width: 2.9160664081573486
#     height: 3.299553394317627
#     heading: 1.5794849395751953
#     velocity_x: -0.0390625
#     velocity_y: 0.37109375
#     valid: true
#   }
#   states {
#     center_x: 316.8656005859375
#     center_y: 7952.52880859375
#     center_z: 121.46456004130694
#     length: 9.346997261047363
#     width: 2.9251766204833984
#     height: 3.3110036849975586
#     heading: 1.587031364440918
#     velocity_x: -0.00244140625
#     velocity_y: -0.478515625
#     valid: true
#   }
#   states {
#     center_x: 316.8712463378906
#     center_y: 7952.4990234375
#     center_z: 121.47109011941147
#     length: 9.149102210998535
#     width: 2.9535679817199707
#     height: 3.2954633235931396
#     heading: 1.5931390523910522
#     velocity_x: 0.05645751953125
#     velocity_y: -0.2978515625
#     valid: true
#   }
#   states {
#     center_x: 316.87921142578125
#     center_y: 7951.9130859375
#     center_z: 121.47680167677571
#     length: 8.81866455078125
#     width: 2.9843528270721436
#     height: 3.2821004390716553
#     heading: 1.5911411046981812
#     velocity_x: 0.07965087890625
#     velocity_y: -5.859375
#     valid: true
#   }
# }
# tracks {
#   id: 260
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 315.6405029296875
#     center_y: 7938.62744140625
#     center_z: 120.72573700425484
#     length: 5.544373512268066
#     width: 2.2813236713409424
#     height: 1.88675856590271
#     heading: 1.5736767053604126
#     velocity_x: 0.013427734375
#     velocity_y: -0.0732421875
#     valid: true
#   }
#   states {
#     center_x: 315.6388854980469
#     center_y: 7938.62744140625
#     center_z: 120.73691826987755
#     length: 5.48790168762207
#     width: 2.267181396484375
#     height: 1.8844265937805176
#     heading: 1.5726717710494995
#     velocity_x: -0.01617431640625
#     velocity_y: -0.0
#     valid: true
#   }
#   states {
#     center_x: 315.6480407714844
#     center_y: 7938.6279296875
#     center_z: 120.73372541838962
#     length: 5.464433670043945
#     width: 2.2976150512695312
#     height: 1.881852388381958
#     heading: 1.5747334957122803
#     velocity_x: 0.091552734375
#     velocity_y: 0.0048828125
#     valid: true
#   }
#   states {
#     center_x: 315.65264892578125
#     center_y: 7938.62890625
#     center_z: 120.73472144216302
#     length: 5.450989723205566
#     width: 2.302509307861328
#     height: 1.8856431245803833
#     heading: 1.572054147720337
#     velocity_x: 0.04608154296875
#     velocity_y: 0.009765625
#     valid: true
#   }
#   states {
#     center_x: 315.6580810546875
#     center_y: 7938.64697265625
#     center_z: 120.72494278491466
#     length: 5.515384197235107
#     width: 2.3236563205718994
#     height: 1.9104059934616089
#     heading: 1.572868824005127
#     velocity_x: 0.0543212890625
#     velocity_y: 0.1806640625
#     valid: true
#   }
#   states {
#     center_x: 315.6636657714844
#     center_y: 7938.66455078125
#     center_z: 120.72933396012209
#     length: 5.484081268310547
#     width: 2.3156955242156982
#     height: 1.9037587642669678
#     heading: 1.5707321166992188
#     velocity_x: 0.05584716796875
#     velocity_y: 0.17578125
#     valid: true
#   }
#   states {
#     center_x: 315.660400390625
#     center_y: 7938.67578125
#     center_z: 120.72599211534676
#     length: 5.489132404327393
#     width: 2.319912910461426
#     height: 1.9110432863235474
#     heading: 1.5720363855361938
#     velocity_x: -0.03265380859375
#     velocity_y: 0.1123046875
#     valid: true
#   }
#   states {
#     center_x: 315.6607360839844
#     center_y: 7938.67431640625
#     center_z: 120.72774517941014
#     length: 5.487973690032959
#     width: 2.3067948818206787
#     height: 1.896347999572754
#     heading: 1.5715663433074951
#     velocity_x: 0.00335693359375
#     velocity_y: -0.0146484375
#     valid: true
#   }
#   states {
#     center_x: 315.67230224609375
#     center_y: 7938.69189453125
#     center_z: 120.72991801249835
#     length: 5.5015764236450195
#     width: 2.3329169750213623
#     height: 1.9121229648590088
#     heading: 1.570508599281311
#     velocity_x: 0.11566162109375
#     velocity_y: 0.17578125
#     valid: true
#   }
#   states {
#     center_x: 315.6711120605469
#     center_y: 7938.67431640625
#     center_z: 120.726224701931
#     length: 5.495301246643066
#     width: 2.3314194679260254
#     height: 1.9191992282867432
#     heading: 1.5709457397460938
#     velocity_x: -0.01190185546875
#     velocity_y: -0.17578125
#     valid: true
#   }
#   states {
#     center_x: 315.6727600097656
#     center_y: 7938.67529296875
#     center_z: 120.72553519728352
#     length: 5.479067802429199
#     width: 2.3285818099975586
#     height: 1.9214162826538086
#     heading: 1.5682250261306763
#     velocity_x: 0.0164794921875
#     velocity_y: 0.009765625
#     valid: true
#   }
# }
# tracks {
#   id: 261
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 269.5179443359375
#     center_y: 7902.17431640625
#     center_z: 122.12289276597359
#     length: 9.397040367126465
#     width: 3.008338451385498
#     height: 3.8250977993011475
#     heading: 0.07286101579666138
#     velocity_x: 0.06195068359375
#     velocity_y: 0.1416015625
#     valid: true
#   }
#   states {
#     center_x: 269.4875793457031
#     center_y: 7902.17822265625
#     center_z: 122.1255291097213
#     length: 9.309864044189453
#     width: 3.029731273651123
#     height: 3.8167166709899902
#     heading: 0.07236232608556747
#     velocity_x: -0.30364990234375
#     velocity_y: 0.0390625
#     valid: true
#   }
#   states {
#     center_x: 269.4906311035156
#     center_y: 7902.1884765625
#     center_z: 122.129080642999
#     length: 9.285928726196289
#     width: 3.0260205268859863
#     height: 3.8098676204681396
#     heading: 0.07396005094051361
#     velocity_x: 0.030517578125
#     velocity_y: 0.1025390625
#     valid: true
#   }
#   states {
#     center_x: 269.4900207519531
#     center_y: 7902.1845703125
#     center_z: 122.11578681081537
#     length: 9.215937614440918
#     width: 3.0306718349456787
#     height: 3.8111789226531982
#     heading: 0.07521886378526688
#     velocity_x: -0.006103515625
#     velocity_y: -0.0390625
#     valid: true
#   }
#   states {
#     center_x: 269.51611328125
#     center_y: 7902.19287109375
#     center_z: 122.1087165886256
#     length: 9.216377258300781
#     width: 3.031684160232544
#     height: 3.818364143371582
#     heading: 0.07476639747619629
#     velocity_x: 0.26092529296875
#     velocity_y: 0.0830078125
#     valid: true
#   }
#   states {
#     center_x: 269.4949645996094
#     center_y: 7902.193359375
#     center_z: 122.09732254654787
#     length: 9.162069320678711
#     width: 3.0494775772094727
#     height: 3.820955753326416
#     heading: 0.07476677745580673
#     velocity_x: -0.21148681640625
#     velocity_y: 0.0048828125
#     valid: true
#   }
#   states {
#     center_x: 269.5568542480469
#     center_y: 7902.19482421875
#     center_z: 122.1001986583155
#     length: 9.15794563293457
#     width: 3.0566015243530273
#     height: 3.8318862915039062
#     heading: 0.07483257353305817
#     velocity_x: 0.618896484375
#     velocity_y: 0.0146484375
#     valid: true
#   }
#   states {
#     center_x: 269.5421142578125
#     center_y: 7902.193359375
#     center_z: 122.09056866573826
#     length: 9.198090553283691
#     width: 3.064439296722412
#     height: 3.827991008758545
#     heading: 0.07046271860599518
#     velocity_x: -0.14739990234375
#     velocity_y: -0.0146484375
#     valid: true
#   }
#   states {
#     center_x: 269.5244140625
#     center_y: 7902.1982421875
#     center_z: 122.08466197001788
#     length: 9.184281349182129
#     width: 3.080157518386841
#     height: 3.8129076957702637
#     heading: 0.07109222561120987
#     velocity_x: -0.177001953125
#     velocity_y: 0.048828125
#     valid: true
#   }
#   states {
#     center_x: 269.55950927734375
#     center_y: 7902.19970703125
#     center_z: 122.09735659890366
#     length: 9.315408706665039
#     width: 3.0442023277282715
#     height: 3.835002899169922
#     heading: 0.066990926861763
#     velocity_x: 0.3509521484375
#     velocity_y: 0.0146484375
#     valid: true
#   }
#   states {
#     center_x: 269.6131286621094
#     center_y: 7902.2021484375
#     center_z: 122.10382346632649
#     length: 9.262551307678223
#     width: 3.0220606327056885
#     height: 3.813972234725952
#     heading: 0.06778893619775772
#     velocity_x: 0.53619384765625
#     velocity_y: 0.0244140625
#     valid: true
#   }
# }
# tracks {
#   id: 262
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 296.5356140136719
#     center_y: 7907.35009765625
#     center_z: 120.85488739487984
#     length: 4.586236953735352
#     width: 2.0895068645477295
#     height: 1.8128151893615723
#     heading: 0.03306928649544716
#     velocity_x: 0.06103515625
#     velocity_y: -0.0
#     valid: true
#   }
#   states {
#     center_x: 296.5316467285156
#     center_y: 7907.34765625
#     center_z: 120.85254174399864
#     length: 4.613109588623047
#     width: 2.103370428085327
#     height: 1.8111608028411865
#     heading: 0.03306019306182861
#     velocity_x: -0.0396728515625
#     velocity_y: -0.0244140625
#     valid: true
#   }
#   states {
#     center_x: 296.5413513183594
#     center_y: 7907.3486328125
#     center_z: 120.85140882903416
#     length: 4.607875823974609
#     width: 2.1029775142669678
#     height: 1.8009591102600098
#     heading: 0.03440207988023758
#     velocity_x: 0.0970458984375
#     velocity_y: 0.009765625
#     valid: true
#   }
#   states {
#     center_x: 296.5405578613281
#     center_y: 7907.345703125
#     center_z: 120.85516669362787
#     length: 4.600801467895508
#     width: 2.101274013519287
#     height: 1.8112218379974365
#     heading: 0.031956084072589874
#     velocity_x: -0.0079345703125
#     velocity_y: -0.029296875
#     valid: true
#   }
#   states {
#     center_x: 296.53082275390625
#     center_y: 7907.3447265625
#     center_z: 120.85165939868419
#     length: 4.6006388664245605
#     width: 2.103271007537842
#     height: 1.8096272945404053
#     heading: 0.03422969579696655
#     velocity_x: -0.09735107421875
#     velocity_y: -0.009765625
#     valid: true
#   }
#   states {
#     center_x: 296.53759765625
#     center_y: 7907.34765625
#     center_z: 120.843446814126
#     length: 4.60611629486084
#     width: 2.109534978866577
#     height: 1.801815152168274
#     heading: 0.03381780534982681
#     velocity_x: 0.0677490234375
#     velocity_y: 0.029296875
#     valid: true
#   }
#   states {
#     center_x: 296.5363464355469
#     center_y: 7907.34765625
#     center_z: 120.84076109728035
#     length: 4.614227771759033
#     width: 2.1100234985351562
#     height: 1.8000009059906006
#     heading: 0.031216058880090714
#     velocity_x: -0.01251220703125
#     velocity_y: -0.0
#     valid: true
#   }
#   states {
#     center_x: 296.5300598144531
#     center_y: 7907.34765625
#     center_z: 120.84851849483982
#     length: 4.61699914932251
#     width: 2.1150460243225098
#     height: 1.809261679649353
#     heading: 0.03432026132941246
#     velocity_x: -0.0628662109375
#     velocity_y: -0.0
#     valid: true
#   }
#   states {
#     center_x: 296.533203125
#     center_y: 7907.34814453125
#     center_z: 120.84802866923663
#     length: 4.625864505767822
#     width: 2.114473819732666
#     height: 1.8212037086486816
#     heading: 0.03458035737276077
#     velocity_x: 0.03143310546875
#     velocity_y: 0.0048828125
#     valid: true
#   }
#   states {
#     center_x: 296.5328674316406
#     center_y: 7907.3486328125
#     center_z: 120.84839419655991
#     length: 4.613743305206299
#     width: 2.112563133239746
#     height: 1.8077106475830078
#     heading: 0.036745887249708176
#     velocity_x: -0.00335693359375
#     velocity_y: 0.0048828125
#     valid: true
#   }
#   states {
#     center_x: 296.5443115234375
#     center_y: 7907.3486328125
#     center_z: 120.85057334425618
#     length: 4.616342544555664
#     width: 2.10404634475708
#     height: 1.815130352973938
#     heading: 0.03708324581384659
#     velocity_x: 0.11444091796875
#     velocity_y: -0.0
#     valid: true
#   }
# }
# tracks {
#   id: 264
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 326.13177490234375
#     center_y: 7911.09326171875
#     center_z: 120.29083862779
#     length: 4.8210859298706055
#     width: 2.1487185955047607
#     height: 1.5115344524383545
#     heading: -3.1309826374053955
#     velocity_x: -0.05645751953125
#     velocity_y: -0.0146484375
#     valid: true
#   }
#   states {
#     center_x: 326.13494873046875
#     center_y: 7911.09033203125
#     center_z: 120.29008752036583
#     length: 4.81804084777832
#     width: 2.151604175567627
#     height: 1.5093189477920532
#     heading: -3.132190704345703
#     velocity_x: 0.03173828125
#     velocity_y: -0.029296875
#     valid: true
#   }
#   states {
#     center_x: 326.1301574707031
#     center_y: 7911.08837890625
#     center_z: 120.29032789641697
#     length: 4.8265838623046875
#     width: 2.1563687324523926
#     height: 1.512088418006897
#     heading: -3.133838653564453
#     velocity_x: -0.04791259765625
#     velocity_y: -0.01953125
#     valid: true
#   }
#   states {
#     center_x: 326.1354675292969
#     center_y: 7911.0859375
#     center_z: 120.2914536198974
#     length: 4.82954216003418
#     width: 2.160187005996704
#     height: 1.5172613859176636
#     heading: -3.135669231414795
#     velocity_x: 0.0531005859375
#     velocity_y: -0.0244140625
#     valid: true
#   }
#   states {
#     center_x: 326.1351623535156
#     center_y: 7911.0830078125
#     center_z: 120.29120407641857
#     length: 4.851380825042725
#     width: 2.1616296768188477
#     height: 1.5179321765899658
#     heading: -3.135829448699951
#     velocity_x: -0.0030517578125
#     velocity_y: -0.029296875
#     valid: true
#   }
#   states {
#     center_x: 326.1583251953125
#     center_y: 7911.08642578125
#     center_z: 120.29162033707522
#     length: 4.845850944519043
#     width: 2.162989377975464
#     height: 1.5128211975097656
#     heading: -3.134891986846924
#     velocity_x: 0.23162841796875
#     velocity_y: 0.0341796875
#     valid: true
#   }
#   states {
#     center_x: 326.1493225097656
#     center_y: 7911.08349609375
#     center_z: 120.29173460802254
#     length: 4.84963321685791
#     width: 2.16144061088562
#     height: 1.5133732557296753
#     heading: -3.1341969966888428
#     velocity_x: -0.09002685546875
#     velocity_y: -0.029296875
#     valid: true
#   }
#   states {
#     center_x: 326.159912109375
#     center_y: 7911.08544921875
#     center_z: 120.28691113399998
#     length: 4.862798690795898
#     width: 2.161405086517334
#     height: 1.513656735420227
#     heading: -3.134052038192749
#     velocity_x: 0.10589599609375
#     velocity_y: 0.01953125
#     valid: true
#   }
#   states {
#     center_x: 326.1639404296875
#     center_y: 7911.0849609375
#     center_z: 120.28552866923663
#     length: 4.8567423820495605
#     width: 2.157059907913208
#     height: 1.515491008758545
#     heading: -3.131256580352783
#     velocity_x: 0.040283203125
#     velocity_y: -0.0048828125
#     valid: true
#   }
#   states {
#     center_x: 326.1664123535156
#     center_y: 7911.08447265625
#     center_z: 120.28666476540756
#     length: 4.862852096557617
#     width: 2.1623618602752686
#     height: 1.5176142454147339
#     heading: -3.1321427822113037
#     velocity_x: 0.02471923828125
#     velocity_y: -0.0048828125
#     valid: true
#   }
#   states {
#     center_x: 326.17138671875
#     center_y: 7911.08251953125
#     center_z: 120.2893474531429
#     length: 4.8716912269592285
#     width: 2.1604723930358887
#     height: 1.5227218866348267
#     heading: -3.1335856914520264
#     velocity_x: 0.04974365234375
#     velocity_y: -0.01953125
#     valid: true
#   }
# }
# tracks {
#   id: 265
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.10787811753609
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.10595971274864
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.10404859954197
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.10139777272943
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.09825668872325
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.0953770509424
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.09251585802254
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.09071362423435
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.08900309550616
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.08824710183335
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.46728515625
#     center_y: 7896.62109375
#     center_z: 121.08758048536946
#     length: 5.81487512588501
#     width: 2.4291508197784424
#     height: 2.014242649078369
#     heading: 6.272405624389648
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
# }
# tracks {
#   id: 266
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 357.47509765625
#     center_y: 7907.521484375
#     center_z: 120.1354431199775
#     length: 5.504321575164795
#     width: 2.353027820587158
#     height: 2.0645854473114014
#     heading: -0.006863433867692947
#     velocity_x: 10.40069580078125
#     velocity_y: -0.048828125
#     valid: true
#   }
#   states {
#     center_z: 0.04383355308067384
#     valid: false
#   }
#   states {
#     center_z: 0.04192243987399673
#     valid: false
#   }
#   states {
#     center_z: 0.0392716130614609
#     valid: false
#   }
#   states {
#     center_z: 0.03613052905529116
#     valid: false
#   }
#   states {
#     center_z: 0.0332508912744391
#     valid: false
#   }
#   states {
#     center_z: 0.030389698354573717
#     valid: false
#   }
#   states {
#     center_z: 0.028587464566383874
#     valid: false
#   }
#   states {
#     center_z: 0.02687693583819582
#     valid: false
#   }
#   states {
#     center_z: 0.026120942165375752
#     valid: false
#   }
#   states {
#     center_z: 0.025454325701492544
#     valid: false
#   }
# }
# tracks {
#   id: 267
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 333.48583984375
#     center_y: 7911.2958984375
#     center_z: 120.18638458726265
#     length: 4.668848514556885
#     width: 2.0774734020233154
#     height: 1.5063319206237793
#     heading: -3.141692638397217
#     velocity_x: 0.091552734375
#     velocity_y: -0.0927734375
#     valid: true
#   }
#   states {
#     center_x: 333.49871826171875
#     center_y: 7911.28662109375
#     center_z: 120.16926079917442
#     length: 4.619086742401123
#     width: 2.081709623336792
#     height: 1.4976752996444702
#     heading: -3.1497106552124023
#     velocity_x: 0.1287841796875
#     velocity_y: -0.0927734375
#     valid: true
#   }
#   states {
#     center_x: 333.5113830566406
#     center_y: 7911.2802734375
#     center_z: 120.16408430510837
#     length: 4.613879203796387
#     width: 2.078270435333252
#     height: 1.4958020448684692
#     heading: -3.15466570854187
#     velocity_x: 0.12664794921875
#     velocity_y: -0.0634765625
#     valid: true
#   }
#   states {
#     center_x: 333.54852294921875
#     center_y: 7911.283203125
#     center_z: 120.16087653249505
#     length: 4.663112163543701
#     width: 2.1005477905273438
#     height: 1.4991075992584229
#     heading: -3.1542019844055176
#     velocity_x: 0.37139892578125
#     velocity_y: 0.029296875
#     valid: true
#   }
#   states {
#     center_x: 333.56964111328125
#     center_y: 7911.287109375
#     center_z: 120.15798721850841
#     length: 4.66410493850708
#     width: 2.0983622074127197
#     height: 1.497409701347351
#     heading: -3.1572418212890625
#     velocity_x: 0.211181640625
#     velocity_y: 0.0390625
#     valid: true
#   }
#   states {
#     center_x: 333.5779724121094
#     center_y: 7911.28125
#     center_z: 120.16380509049318
#     length: 4.688409805297852
#     width: 2.0987253189086914
#     height: 1.501232385635376
#     heading: -3.152783155441284
#     velocity_x: 0.08331298828125
#     velocity_y: -0.05859375
#     valid: true
#   }
#   states {
#     center_x: 333.5438232421875
#     center_y: 7911.2841796875
#     center_z: 120.16437712511238
#     length: 4.693107604980469
#     width: 2.097776174545288
#     height: 1.5050334930419922
#     heading: -3.1538901329040527
#     velocity_x: -0.34149169921875
#     velocity_y: 0.029296875
#     valid: true
#   }
#   states {
#     center_x: 333.51605224609375
#     center_y: 7911.27783203125
#     center_z: 120.15606701778904
#     length: 4.669130802154541
#     width: 2.0861551761627197
#     height: 1.5002968311309814
#     heading: -3.152820348739624
#     velocity_x: -0.2777099609375
#     velocity_y: -0.0634765625
#     valid: true
#   }
#   states {
#     center_x: 333.4861755371094
#     center_y: 7911.28271484375
#     center_z: 120.15984965312335
#     length: 4.684072017669678
#     width: 2.0903666019439697
#     height: 1.4988590478897095
#     heading: -3.1521213054656982
#     velocity_x: -0.29876708984375
#     velocity_y: 0.048828125
#     valid: true
#   }
#   states {
#     center_x: 333.4556884765625
#     center_y: 7911.28125
#     center_z: 120.15989474587631
#     length: 4.652885437011719
#     width: 2.0799031257629395
#     height: 1.4945327043533325
#     heading: -3.150479555130005
#     velocity_x: -0.30487060546875
#     velocity_y: -0.0146484375
#     valid: true
#   }
#   states {
#     center_x: 333.4106750488281
#     center_y: 7911.2880859375
#     center_z: 120.1619060468929
#     length: 4.644349098205566
#     width: 2.077028751373291
#     height: 1.4895405769348145
#     heading: -3.150261163711548
#     velocity_x: -0.45013427734375
#     velocity_y: 0.068359375
#     valid: true
#   }
# }
# tracks {
#   id: 269
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 312.0057373046875
#     center_y: 7923.4765625
#     center_z: 120.54050293443062
#     length: 4.342202663421631
#     width: 2.0743048191070557
#     height: 1.6040326356887817
#     heading: -1.554589033126831
#     velocity_x: 0.00152587890625
#     velocity_y: -0.7568359375
#     valid: true
#   }
#   states {
#     center_x: 312.0085144042969
#     center_y: 7923.40673828125
#     center_z: 120.53750115561974
#     length: 4.325821876525879
#     width: 2.0736050605773926
#     height: 1.611027479171753
#     heading: -1.5533525943756104
#     velocity_x: 0.02777099609375
#     velocity_y: -0.6982421875
#     valid: true
#   }
#   states {
#     center_x: 312.013427734375
#     center_y: 7923.33349609375
#     center_z: 120.53013502532322
#     length: 4.34622859954834
#     width: 2.0723307132720947
#     height: 1.5963160991668701
#     heading: -1.5553632974624634
#     velocity_x: 0.04913330078125
#     velocity_y: -0.732421875
#     valid: true
#   }
#   states {
#     center_x: 312.01947021484375
#     center_y: 7923.2568359375
#     center_z: 120.52120520681146
#     length: 4.353935718536377
#     width: 2.0670952796936035
#     height: 1.5798522233963013
#     heading: -1.5544416904449463
#     velocity_x: 0.0604248046875
#     velocity_y: -0.7666015625
#     valid: true
#   }
#   states {
#     center_x: 312.0223693847656
#     center_y: 7923.18115234375
#     center_z: 120.52316055835216
#     length: 4.3656158447265625
#     width: 2.0692927837371826
#     height: 1.5836058855056763
#     heading: -1.5546842813491821
#     velocity_x: 0.02899169921875
#     velocity_y: -0.7568359375
#     valid: true
#   }
#   states {
#     center_x: 312.0279541015625
#     center_y: 7923.10107421875
#     center_z: 120.51968582779787
#     length: 4.357097625732422
#     width: 2.069105863571167
#     height: 1.5795129537582397
#     heading: -1.5535610914230347
#     velocity_x: 0.05584716796875
#     velocity_y: -0.80078125
#     valid: true
#   }
#   states {
#     center_x: 312.0303955078125
#     center_y: 7923.04052734375
#     center_z: 120.51590147813972
#     length: 4.357729911804199
#     width: 2.0661041736602783
#     height: 1.5770962238311768
#     heading: -1.5528947114944458
#     velocity_x: 0.0244140625
#     velocity_y: -0.60546875
#     valid: true
#   }
#   states {
#     center_x: 312.0364990234375
#     center_y: 7922.94775390625
#     center_z: 120.50983441280857
#     length: 4.375572681427002
#     width: 2.0677876472473145
#     height: 1.5781941413879395
#     heading: -1.5514702796936035
#     velocity_x: 0.06103515625
#     velocity_y: -0.927734375
#     valid: true
#   }
#   states {
#     center_x: 312.0426025390625
#     center_y: 7922.86572265625
#     center_z: 120.509497175096
#     length: 4.373758792877197
#     width: 2.0626273155212402
#     height: 1.5775871276855469
#     heading: -1.549677848815918
#     velocity_x: 0.06103515625
#     velocity_y: -0.8203125
#     valid: true
#   }
#   states {
#     center_x: 312.04644775390625
#     center_y: 7922.75927734375
#     center_z: 120.51464633279038
#     length: 4.366183280944824
#     width: 2.065229892730713
#     height: 1.5926806926727295
#     heading: -1.5500624179840088
#     velocity_x: 0.0384521484375
#     velocity_y: -1.064453125
#     valid: true
#   }
#   states {
#     center_x: 312.0501708984375
#     center_y: 7922.66357421875
#     center_z: 120.51546744826008
#     length: 4.376238822937012
#     width: 2.0646214485168457
#     height: 1.5871222019195557
#     heading: -1.5496066808700562
#     velocity_x: 0.0372314453125
#     velocity_y: -0.95703125
#     valid: true
#   }
# }
# tracks {
#   id: 270
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.28643646714546
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.28451806235802
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.28260694915134
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.2799561223388
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.27681503833263
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.27393540055178
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.27107420763191
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.26927197384373
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.26756144511553
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.26680545144272
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 272.1589660644531
#     center_y: 7898.5283203125
#     center_z: 121.26613883497883
#     length: 5.594817638397217
#     width: 2.3755834102630615
#     height: 1.9722262620925903
#     heading: 6.247772693634033
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
# }
# tracks {
#   id: 271
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.52313080308296
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.52121239829552
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.51930128508884
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.5166504582763
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.51350937427013
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.51062973648928
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.50776854356941
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.50596630978123
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.50425578105303
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.50349978738022
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 293.9437561035156
#     center_y: 7886.10791015625
#     center_z: 121.50283317091633
#     length: 4.840170383453369
#     width: 2.152933120727539
#     height: 2.3423662185668945
#     heading: 0.0522724986076355
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
# }
# tracks {
#   id: 272
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 351.5095520019531
#     center_y: 7907.53076171875
#     center_z: 120.38396301743843
#     length: 5.672352313995361
#     width: 2.828554153442383
#     height: 2.291806697845459
#     heading: -0.011098477058112621
#     velocity_x: 9.92156982421875
#     velocity_y: -0.1220703125
#     valid: true
#   }
#   states {
#     center_x: 352.4686584472656
#     center_y: 7907.5244140625
#     center_z: 120.3752849690963
#     length: 5.70259428024292
#     width: 2.814671277999878
#     height: 2.297308921813965
#     heading: -0.011598781682550907
#     velocity_x: 9.591064453125
#     velocity_y: -0.0634765625
#     valid: true
#   }
#   states {
#     center_x: 353.4640197753906
#     center_y: 7907.513671875
#     center_z: 120.34879194670994
#     length: 5.759884834289551
#     width: 2.806279182434082
#     height: 2.3385820388793945
#     heading: -0.011624760925769806
#     velocity_x: 9.95361328125
#     velocity_y: -0.107421875
#     valid: true
#   }
#   states {
#     center_x: 354.31719970703125
#     center_y: 7907.5234375
#     center_z: 120.3385498723388
#     length: 5.721709728240967
#     width: 2.8045389652252197
#     height: 2.3047540187835693
#     heading: -0.008921278640627861
#     velocity_x: 8.53179931640625
#     velocity_y: 0.09765625
#     valid: true
#   }
#   states {
#     center_x: 355.3359680175781
#     center_y: 7907.51171875
#     center_z: 120.32699356616466
#     length: 5.838263988494873
#     width: 2.8215413093566895
#     height: 2.32586669921875
#     heading: -0.005528294015675783
#     velocity_x: 10.18768310546875
#     velocity_y: -0.1171875
#     valid: true
#   }
#   states {
#     center_x: 356.2402038574219
#     center_y: 7907.505859375
#     center_z: 120.31286820084475
#     length: 5.839654922485352
#     width: 2.8230843544006348
#     height: 2.3005597591400146
#     heading: -0.0059002116322517395
#     velocity_x: 9.0423583984375
#     velocity_y: -0.05859375
#     valid: true
#   }
#   states {
#     center_x: 357.3060607910156
#     center_y: 7907.49072265625
#     center_z: 120.29568663438972
#     length: 5.943305969238281
#     width: 2.819242000579834
#     height: 2.3449532985687256
#     heading: -0.006741535849869251
#     velocity_x: 10.6585693359375
#     velocity_y: -0.1513671875
#     valid: true
#   }
#   states {
#     center_x: 358.25518798828125
#     center_y: 7907.47900390625
#     center_z: 120.28541577267185
#     length: 5.9990668296813965
#     width: 2.8138365745544434
#     height: 2.3332321643829346
#     heading: -0.003919608425348997
#     velocity_x: 9.49127197265625
#     velocity_y: -0.1171875
#     valid: true
#   }
#   states {
#     center_x: 359.1446228027344
#     center_y: 7907.4814453125
#     center_z: 120.26724863993975
#     length: 5.969986438751221
#     width: 2.8140220642089844
#     height: 2.3039474487304688
#     heading: 0.00024847290478646755
#     velocity_x: 8.89434814453125
#     velocity_y: 0.0244140625
#     valid: true
#   }
#   states {
#     center_x: 360.091552734375
#     center_y: 7907.4765625
#     center_z: 120.25441531472397
#     length: 6.032472610473633
#     width: 2.8161776065826416
#     height: 2.2777116298675537
#     heading: 0.0022105961106717587
#     velocity_x: 9.46929931640625
#     velocity_y: -0.048828125
#     valid: true
#   }
#   states {
#     center_x: 361.1556701660156
#     center_y: 7907.47802734375
#     center_z: 120.22759513380696
#     length: 6.098978519439697
#     width: 2.8046021461486816
#     height: 2.2931101322174072
#     heading: 0.0009092586115002632
#     velocity_x: 10.64117431640625
#     velocity_y: 0.0146484375
#     valid: true
#   }
# }
# tracks {
#   id: 273
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 275.5858459472656
#     center_y: 7913.3701171875
#     center_z: 120.85588684556343
#     length: 4.437084674835205
#     width: 1.973414421081543
#     height: 1.569638729095459
#     heading: -3.057790756225586
#     velocity_x: -11.50665283203125
#     velocity_y: -1.0888671875
#     valid: true
#   }
#   states {
#     center_x: 274.3872375488281
#     center_y: 7913.27783203125
#     center_z: 120.87034112144005
#     length: 4.479778289794922
#     width: 1.9809510707855225
#     height: 1.570973515510559
#     heading: -3.0588603019714355
#     velocity_x: -11.986083984375
#     velocity_y: -0.9228515625
#     valid: true
#   }
#   states {
#     center_x: 273.2207336425781
#     center_y: 7913.16845703125
#     center_z: 120.8827656405576
#     length: 4.456454277038574
#     width: 1.9927953481674194
#     height: 1.569103717803955
#     heading: -3.0556230545043945
#     velocity_x: -11.6650390625
#     velocity_y: -1.09375
#     valid: true
#   }
#   states {
#     center_x: 272.0480651855469
#     center_y: 7913.07080078125
#     center_z: 120.89715125173333
#     length: 4.451054573059082
#     width: 1.973827838897705
#     height: 1.5650299787521362
#     heading: -3.0569489002227783
#     velocity_x: -11.7266845703125
#     velocity_y: -0.9765625
#     valid: true
#   }
#   states {
#     center_x: 270.86920166015625
#     center_y: 7912.96826171875
#     center_z: 120.90797195971935
#     length: 4.473241806030273
#     width: 1.9870891571044922
#     height: 1.5398790836334229
#     heading: -3.0553464889526367
#     velocity_x: -11.78863525390625
#     velocity_y: -1.025390625
#     valid: true
#   }
#   states {
#     center_x: 269.7357482910156
#     center_y: 7912.8623046875
#     center_z: 120.92133530289553
#     length: 4.496996879577637
#     width: 1.9760613441467285
#     height: 1.5483423471450806
#     heading: -3.054513692855835
#     velocity_x: -11.33453369140625
#     velocity_y: -1.0595703125
#     valid: true
#   }
#   states {
#     center_x: 268.5406494140625
#     center_y: 7912.759765625
#     center_z: 120.94558897813972
#     length: 4.511602401733398
#     width: 1.9933464527130127
#     height: 1.5586367845535278
#     heading: -3.054762363433838
#     velocity_x: -11.95098876953125
#     velocity_y: -1.025390625
#     valid: true
#   }
#   states {
#     center_x: 267.3910827636719
#     center_y: 7912.65576171875
#     center_z: 120.95610821651951
#     length: 4.497663974761963
#     width: 1.9830824136734009
#     height: 1.5709950923919678
#     heading: -3.052443027496338
#     velocity_x: -11.49566650390625
#     velocity_y: -1.0400390625
#     valid: true
#   }
#   states {
#     center_x: 266.2415466308594
#     center_y: 7912.55224609375
#     center_z: 120.98387766826006
#     length: 4.509607315063477
#     width: 1.9945366382598877
#     height: 1.5752066373825073
#     heading: -3.057278871536255
#     velocity_x: -11.495361328125
#     velocity_y: -1.03515625
#     valid: true
#   }
#   states {
#     center_x: 265.0537109375
#     center_y: 7912.44189453125
#     center_z: 121.00950412087631
#     length: 4.513803482055664
#     width: 1.9952468872070312
#     height: 1.571396827697754
#     heading: -3.053684711456299
#     velocity_x: -11.87835693359375
#     velocity_y: -1.103515625
#     valid: true
#   }
#   states {
#     center_x: 263.9065856933594
#     center_y: 7912.34375
#     center_z: 121.02068595411946
#     length: 4.495596885681152
#     width: 1.9967730045318604
#     height: 1.5647225379943848
#     heading: -3.0556163787841797
#     velocity_x: -11.47125244140625
#     velocity_y: -0.9814453125
#     valid: true
#   }
# }
# tracks {
#   id: 274
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.43176880357125
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.4298503987838
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.42793928557712
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.42528845876458
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.42214737475841
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.41926773697756
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.4164065440577
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.41460431026951
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.41289378154131
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.4121377878685
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 294.48736572265625
#     center_y: 7880.7333984375
#     center_z: 121.41147117140461
#     length: 5.686858654022217
#     width: 2.3556458950042725
#     height: 2.156019926071167
#     heading: -3.162618637084961
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
# }
# tracks {
#   id: 275
#   object_type: TYPE_VEHICLE
#   states {
#     center_x: 279.44921875
#     center_y: 7887.01904296875
#     center_z: 121.50721588609078
#     length: 4.974858283996582
#     width: 2.2164554595947266
#     height: 1.9366506338119507
#     heading: -3.128615379333496
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 279.44921875
#     center_y: 7887.01904296875
#     center_z: 121.50529748130333
#     length: 4.974858283996582
#     width: 2.2164554595947266
#     height: 1.9366506338119507
#     heading: -3.128615379333496
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 279.44921875
#     center_y: 7887.01904296875
#     center_z: 121.50338636809666
#     length: 4.974858283996582
#     width: 2.2164554595947266
#     height: 1.9366506338119507
#     heading: -3.128615379333496
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 279.44921875
#     center_y: 7887.01904296875
#     center_z: 121.50073554128412
#     length: 4.974858283996582
#     width: 2.2164554595947266
#     height: 1.9366506338119507
#     heading: -3.128615379333496
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 279.44921875
#     center_y: 7887.01904296875
#     center_z: 121.49759445727794
#     length: 4.974858283996582
#     width: 2.2164554595947266
#     height: 1.9366506338119507
#     heading: -3.128615379333496
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 279.44921875
#     center_y: 7887.01904296875
#     center_z: 121.49471481949709
#     length: 4.974858283996582
#     width: 2.2164554595947266
#     height: 1.9366506338119507
#     heading: -3.128615379333496
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 279.44921875
#     center_y: 7887.01904296875
#     center_z: 121.49185362657722
#     length: 4.974858283996582
#     width: 2.2164554595947266
#     height: 1.9366506338119507
#     heading: -3.128615379333496
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 279.44921875
#     center_y: 7887.01904296875
#     center_z: 121.49005139278904
#     length: 4.974858283996582
#     width: 2.2164554595947266
#     height: 1.9366506338119507
#     heading: -3.128615379333496
#     velocity_x: 0.0
#     velocity_y: 0.0
#     valid: true
#   }
#   states {
#     center_x: 279.44921875
#     center_y: 7887.01904296875
#     center_z: 121.48834086406085
#     length: 4.974858283996582
#     width: 2.2164554595947266
#     height: 1.9366506338119507
#     heading: -3.128615379333496
# ...
#       z: 119.69341416316207
#     }
#     polyline {
#       x: 318.67764200937285
#       y: 7845.313169308129
#       z: 119.69249863581832
#     }
#     polyline {
#       x: 318.74125128380905
#       y: 7845.807418577166
#       z: 119.69158310847457
#     }
#     polyline {
#       x: 318.8027060570882
#       y: 7846.301940322092
#       z: 119.69066758113082
#     }
#     polyline {
#       x: 318.8618964924046
#       y: 7846.79673816409
#       z: 119.68975205378707
#     }
#     polyline {
#       x: 318.91872088808157
#       y: 7847.291813278171
#       z: 119.68883652644332
#     }
#     polyline {
#       x: 318.973086242309
#       y: 7847.787164425488
#       z: 119.68789048152145
#     }
#     polyline {
#       x: 319.0249088112677
#       y: 7848.282788018749
#       z: 119.6869749541777
#     }
#     polyline {
#       x: 319.07411467518955
#       y: 7848.77867821284
#       z: 119.68605942683395
#     }
#     polyline {
#       x: 319.12064030574004
#       y: 7849.274827030132
#       z: 119.6851438994902
#     }
#     polyline {
#       x: 319.16443312546556
#       y: 7849.771224508636
#       z: 119.68422837214645
#     }
#     polyline {
#       x: 319.20545208707904
#       y: 7850.267858884046
#       z: 119.6833128448027
#     }
#     polyline {
#       x: 319.2436682289393
#       y: 7850.76471679149
#       z: 119.68239731745895
#     }
#     polyline {
#       x: 319.2790652384663
#       y: 7851.261783494063
#       z: 119.6814817901152
#     }
#     polyline {
#       x: 319.3116400248134
#       y: 7851.7590431294975
#       z: 119.68053574519332
#     }
#     polyline {
#       x: 319.34140326773473
#       y: 7852.256478978896
#       z: 119.67962021784957
#     }
#     polyline {
#       x: 319.3683799743865
#       y: 7852.754073745704
#       z: 119.67870469050582
#     }
#     polyline {
#       x: 319.39261003480703
#       y: 7853.251809844933
#       z: 119.67778916316207
#     }
#     polyline {
#       x: 319.41414877078296
#       y: 7853.749669699477
#       z: 119.67687363581832
#     }
#     polyline {
#       x: 319.4330674714904
#       y: 7854.247636036424
#       z: 119.67595810847457
#     }
#     polyline {
#       x: 319.4494539397163
#       y: 7854.745692173915
#       z: 119.67504258113082
#     }
#     polyline {
#       x: 319.4634130248542
#       y: 7855.243822302482
#       z: 119.67412705378707
#     }
#     polyline {
#       x: 319.47506715457763
#       y: 7855.742011738024
#       z: 119.6731810088652
#     }
#     polyline {
#       x: 319.4845568625452
#       y: 7856.240247158221
#       z: 119.67226548152145
#     }
#     polyline {
#       x: 319.492041314784
#       y: 7856.738516792465
#       z: 119.6713499541777
#     }
#     polyline {
#       x: 319.4976988387172
#       y: 7857.236810576317
#       z: 119.67043442683395
#     }
#     polyline {
#       x: 319.5017274389668
#       y: 7857.735120250019
#       z: 119.6695188994902
#     }
#     polyline {
#       x: 319.5043453277039
#       y: 7858.233439385285
#       z: 119.66860337214645
#     }
#     polyline {
#       x: 319.50579145367715
#       y: 7858.731763347479
#       z: 119.6676878448027
#     }
#     polyline {
#       x: 319.50632602198255
#       y: 7859.230089162424
#       z: 119.66674179988082
#     }
#     polyline {
#       x: 319.5062310310268
#       y: 7859.7284152855045
#       z: 119.66582627253707
#     }
#     polyline {
#       x: 319.505810804201
#       y: 7860.226741258063
#       z: 119.66491074519332
#     }
#     entry_lanes: 170
#     exit_lanes: 82
#     left_neighbors {
#       feature_id: 151
#       self_start_index: 0
#       self_end_index: 20
#       neighbor_start_index: 0
#       neighbor_end_index: 20
#       boundaries {
#         lane_start_index: 0
#         lane_end_index: 20
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     left_neighbors {
#       feature_id: 150
#       self_start_index: 0
#       self_end_index: 46
#       neighbor_start_index: 0
#       neighbor_end_index: 46
#       boundaries {
#         lane_start_index: 0
#         lane_end_index: 46
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     left_neighbors {
#       feature_id: 83
#       self_start_index: 44
#       self_end_index: 87
#       neighbor_start_index: 0
#       neighbor_end_index: 40
#       boundaries {
#         lane_start_index: 44
#         lane_end_index: 87
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     left_boundaries {
#       lane_start_index: 0
#       lane_end_index: 26
#       boundary_feature_id: 39
#       boundary_type: TYPE_SOLID_DOUBLE_YELLOW
#     }
#     right_boundaries {
#       lane_start_index: 1
#       lane_end_index: 43
#       boundary_feature_id: 45
#       boundary_type: TYPE_UNKNOWN
#     }
#     right_boundaries {
#       lane_start_index: 43
#       lane_end_index: 87
#       boundary_feature_id: 40
#       boundary_type: TYPE_UNKNOWN
#     }
#   }
# }
# map_features {
#   id: 195
#   lane {
#     speed_limit_mph: 25.0
#     type: TYPE_SURFACE_STREET
#     interpolating: true
#     polyline {
#       x: 213.16292191386214
#       y: 7902.881920211934
#       z: 121.00158066706832
#     }
#     polyline {
#       x: 213.64594917518457
#       y: 7902.940415034467
#       z: 120.9977659698027
#     }
#     polyline {
#       x: 214.13121583740963
#       y: 7902.976193986402
#       z: 120.99395127253707
#     }
#     polyline {
#       x: 214.6174164259315
#       y: 7902.995946661303
#       z: 120.99016709284957
#     }
#     polyline {
#       x: 215.10393086167198
#       y: 7903.00565257198
#       z: 120.98635239558395
#     }
#     polyline {
#       x: 215.59052452862224
#       y: 7903.0102177786375
#       z: 120.98253769831832
#     }
#     polyline {
#       x: 216.07713165801405
#       y: 7903.01314022325
#       z: 120.9787230010527
#     }
#     polyline {
#       x: 216.56373803618604
#       y: 7903.016186384562
#       z: 120.97490830378707
#     }
#     exit_lanes: 145
#     left_neighbors {
#       feature_id: 205
#       self_start_index: 0
#       self_end_index: 7
#       neighbor_start_index: 0
#       neighbor_end_index: 7
#       boundaries {
#         lane_start_index: 0
#         lane_end_index: 7
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     left_neighbors {
#       feature_id: 199
#       self_start_index: 1
#       self_end_index: 7
#       neighbor_start_index: 2
#       neighbor_end_index: 7
#       boundaries {
#         lane_start_index: 1
#         lane_end_index: 7
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     left_neighbors {
#       feature_id: 200
#       self_start_index: 1
#       self_end_index: 7
#       neighbor_start_index: 2
#       neighbor_end_index: 8
#       boundaries {
#         lane_start_index: 1
#         lane_end_index: 7
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     right_boundaries {
#       lane_start_index: 5
#       lane_end_index: 7
#       boundary_feature_id: 48
#       boundary_type: TYPE_UNKNOWN
#     }
#   }
# }
# map_features {
#   id: 199
#   lane {
#     speed_limit_mph: 25.0
#     type: TYPE_SURFACE_STREET
#     interpolating: true
#     polyline {
#       x: 213.10644063520363
#       y: 7903.244567423705
#       z: 121.0215696807402
#     }
#     polyline {
#       x: 213.59489530251162
#       y: 7903.1590841696625
#       z: 121.01491684870895
#     }
#     polyline {
#       x: 214.08680472407556
#       y: 7903.096391471586
#       z: 121.0082640166777
#     }
#     polyline {
#       x: 214.58087544480722
#       y: 7903.053854239506
#       z: 121.00158066706832
#     }
#     polyline {
#       x: 215.07612813325397
#       y: 7903.028365049939
#       z: 120.99492783503707
#     }
#     polyline {
#       x: 215.57189945171328
#       y: 7903.016353501836
#       z: 120.9882444854277
#     }
#     polyline {
#       x: 216.06781637456524
#       y: 7903.01379066683
#       z: 120.98159165339645
#     }
#     polyline {
#       x: 216.56373803618604
#       y: 7903.016186384562
#       z: 120.97490830378707
#     }
#     exit_lanes: 145
#     left_neighbors {
#       feature_id: 200
#       self_start_index: 0
#       self_end_index: 7
#       neighbor_start_index: 0
#       neighbor_end_index: 8
#       boundaries {
#         lane_start_index: 0
#         lane_end_index: 7
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     right_neighbors {
#       feature_id: 205
#       self_start_index: 1
#       self_end_index: 7
#       neighbor_start_index: 1
#       neighbor_end_index: 7
#       boundaries {
#         lane_start_index: 1
#         lane_end_index: 7
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     right_neighbors {
#       feature_id: 195
#       self_start_index: 2
#       self_end_index: 7
#       neighbor_start_index: 1
#       neighbor_end_index: 7
#       boundaries {
#         lane_start_index: 2
#         lane_end_index: 7
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     right_boundaries {
#       lane_start_index: 5
#       lane_end_index: 7
#       boundary_feature_id: 48
#       boundary_type: TYPE_UNKNOWN
#     }
#   }
# }
# map_features {
#   id: 200
#   lane {
#     speed_limit_mph: 25.0
#     type: TYPE_SURFACE_STREET
#     interpolating: true
#     polyline {
#       x: 212.881650772462
#       y: 7907.245265903199
#       z: 121.02993149714645
#     }
#     polyline {
#       x: 213.37400599406817
#       y: 7907.162338367893
#       z: 121.02428574519332
#     }
#     polyline {
#       x: 213.86926981194273
#       y: 7907.098995937075
#       z: 121.01867051081832
#     }
#     polyline {
#       x: 214.366441548351
#       y: 7907.052886439378
#       z: 121.01305527644332
#     }
#     polyline {
#       x: 214.8647641178505
#       y: 7907.021470237417
#       z: 121.0074095244902
#     }
#     polyline {
#       x: 215.36370369542044
#       y: 7907.002047652606
#       z: 121.0017942901152
#     }
#     polyline {
#       x: 215.8629200697288
#       y: 7906.991782042212
#       z: 120.9961790557402
#     }
#     polyline {
#       x: 216.36222855575767
#       y: 7906.987718473448
#       z: 120.99053330378707
#     }
#     polyline {
#       x: 216.86155435687488
#       y: 7906.9867984517105
#       z: 120.98491806941207
#     }
#     exit_lanes: 142
#     right_neighbors {
#       feature_id: 199
#       self_start_index: 0
#       self_end_index: 8
#       neighbor_start_index: 0
#       neighbor_end_index: 7
#       boundaries {
#         lane_start_index: 0
#         lane_end_index: 8
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     right_neighbors {
#       feature_id: 205
#       self_start_index: 1
#       self_end_index: 8
#       neighbor_start_index: 0
#       neighbor_end_index: 7
#       boundaries {
#         lane_start_index: 1
#         lane_end_index: 8
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     right_neighbors {
#       feature_id: 195
#       self_start_index: 2
#       self_end_index: 8
#       neighbor_start_index: 1
#       neighbor_end_index: 7
#       boundaries {
#         lane_start_index: 2
#         lane_end_index: 8
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     right_boundaries {
#       lane_start_index: 8
#       lane_end_index: 8
#       boundary_feature_id: 35
#       boundary_type: TYPE_PASSING_DOUBLE_YELLOW
#     }
#   }
# }
# map_features {
#   id: 205
#   lane {
#     speed_limit_mph: 25.0
#     type: TYPE_SURFACE_STREET
#     interpolating: false
#     polyline {
#       x: 213.0851662082588
#       y: 7902.993897510622
#       z: 121.01723618464645
#     }
#     polyline {
#       x: 213.58210529928786
#       y: 7902.997041350811
#       z: 121.0111937041777
#     }
#     polyline {
#       x: 214.07904435460748
#       y: 7903.000190694091
#       z: 121.00515122370895
#     }
#     polyline {
#       x: 214.57598334644373
#       y: 7903.003349911883
#       z: 120.9991087432402
#     }
#     polyline {
#       x: 215.07292224702266
#       y: 7903.006523753886
#       z: 120.99306626277145
#     }
#     polyline {
#       x: 215.5698610193123
#       y: 7903.009717356736
#       z: 120.9870237823027
#     }
#     polyline {
#       x: 216.06679963024834
#       y: 7903.012936252683
#       z: 120.98095078425582
#     }
#     polyline {
#       x: 216.56373803618604
#       y: 7903.016186384562
#       z: 120.97490830378707
#     }
#     exit_lanes: 145
#     left_neighbors {
#       feature_id: 200
#       self_start_index: 0
#       self_end_index: 7
#       neighbor_start_index: 1
#       neighbor_end_index: 8
#       boundaries {
#         lane_start_index: 0
#         lane_end_index: 7
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     left_neighbors {
#       feature_id: 199
#       self_start_index: 1
#       self_end_index: 7
#       neighbor_start_index: 1
#       neighbor_end_index: 7
#       boundaries {
#         lane_start_index: 1
#         lane_end_index: 7
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     right_neighbors {
#       feature_id: 195
#       self_start_index: 0
#       self_end_index: 7
#       neighbor_start_index: 0
#       neighbor_end_index: 7
#       boundaries {
#         lane_start_index: 0
#         lane_end_index: 7
#         boundary_feature_id: 0
#         boundary_type: TYPE_UNKNOWN
#       }
#     }
#     right_boundaries {
#       lane_start_index: 5
#       lane_end_index: 7
#       boundary_feature_id: 48
#       boundary_type: TYPE_UNKNOWN
#     }
#   }
# }
# map_features {
#   id: 208
#   crosswalk {
#     polygon {
#       x: 326.16945099035996
#       y: 7901.097426922332
#       z: 119.74489731745895
#     }
#     polygon {
#       x: 299.9802282463872
#       y: 7901.152882397991
#       z: 119.74489731745895
#     }
#     polygon {
#       x: 299.97092148690297
#       y: 7897.770098374094
#       z: 119.74489731745895
#     }
#     polygon {
#       x: 326.16014423087574
#       y: 7897.714642898435
#       z: 119.74489731745895
#     }
#   }
# }
# map_features {
#   id: 209
#   crosswalk {
#     polygon {
#       x: 325.1736276660314
#       y: 7898.147195609209
#       z: 119.50991196589645
#     }
#     polygon {
#       x: 324.5779950246537
#       y: 7924.621639756342
#       z: 119.50991196589645
#     }
#     polygon {
#       x: 321.22756141062195
#       y: 7924.544002090104
#       z: 119.50991196589645
#     }
#     polygon {
#       x: 321.8231940533222
#       y: 7898.06955794297
#       z: 119.50991196589645
#     }
#   }
# }
# map_features {
#   id: 210
#   crosswalk {
#     polygon {
#       x: 303.27482129954586
#       y: 7896.117525194872
#       z: 119.85491318659957
#     }
#     polygon {
#       x: 303.21898073999535
#       y: 7925.231649990173
#       z: 119.85491318659957
#     }
#     polygon {
#       x: 299.8964674070614
#       y: 7925.220558894883
#       z: 119.85491318659957
#     }
#     polygon {
#       x: 299.96161472741875
#       y: 7896.106434100369
#       z: 119.85491318659957
#     }
#   }
# }
# map_features {
#   id: 211
#   crosswalk {
#     polygon {
#       x: 326.55102815169715
#       y: 7920.662118783695
#       z: 119.65493149714645
#     }
#     polygon {
#       x: 326.5231078719219
#       y: 7923.967265141354
#       z: 119.65493149714645
#     }
#     polygon {
#       x: 297.4953233172918
#       y: 7923.767625428507
#       z: 119.65493149714645
#     }
#     polygon {
#       x: 297.5232435970671
#       y: 7920.4624790708485
#       z: 119.65493149714645
#     }
#   }
# }
# map_features {
#   id: 212
#   stop_sign {
#     lane: 65
#     lane: 64
#     lane: 63
#     position {
#       x: 425.9844523851904
#       y: 7925.808386938134
#       z: 120.76112612509816
#     }
#   }
# }
# map_features {
#   id: 213
#   stop_sign {
#     lane: 195
#     position {
#       x: 215.74474315396105
#       y: 7895.452059485381
#       z: 123.65278012024847
#     }
#   }
# }
# map_features {
#   id: 214
# }
# map_features {
#   id: 215
# }
# map_features {
#   id: 216
# }
# map_features {
#   id: 217
# }
# map_features {
#   id: 218
# }
# map_features {
#   id: 219
# }
# map_features {
#   id: 220
# }
# map_features {
#   id: 221
# }
# map_features {
#   id: 222
# }
# map_features {
#   id: 223
# }
# map_features {
#   id: 224
# }
# map_features {
#   id: 225
# }
# map_features {
#   id: 226
# }
# map_features {
#   id: 227
# }
# map_features {
#   id: 228
# }
# map_features {
#   id: 229
# }
# map_features {
#   id: 230
# }
# map_features {
#   id: 231
# }
# map_features {
#   id: 232
# }
# map_features {
#   id: 233
# }
# map_features {
#   id: 234
# }
# map_features {
#   id: 235
# }
# map_features {
#   id: 236
# }
# map_features {
#   id: 237
# }
# map_features {
#   id: 238
# }
# map_features {
#   id: 239
# }
# map_features {
#   id: 240
# }
# map_features {
#   id: 241
# }
# current_time_index: 10
# tracks_to_predict {
#   track_index: 15
#   difficulty: NONE
# }
# tracks_to_predict {
#   track_index: 8
#   difficulty: NONE
# }
# tracks_to_predict {
#   track_index: 18
#   difficulty: NONE
# }

# %%
np.savetxt("output.txt", track_infos, fmt='%s')

# %%
scenario.tracks_to_predict[0].track_index
# Out:
# 0

# %%
import numpy as np
import cv2
import os

def plot_map_features(map_infos, save_path="map.png", meta_path="meta.txt"):
    color_map = {
        'lane': [219, 225, 200],
        'road_line': [40, 40, 40],
        'road_edge': [0, 0, 0],
        'stop_sign': [0, 0, 255],
        'crosswalk': [116, 116, 116],
        'speed_bump': [53, 209, 243],
        'rest': [243, 240, 255]
    }

    dark_color_map = {
        'lane': [246, 9, 0],
        'road_line': [219, 225, 200],
        # 'road_line': [20, 20, 20],
        # 'road_edge': [179, 185, 160],
        'road_edge': [20, 20, 20],
        'stop_sign': [0, 0, 255],
        'crosswalk': [116, 116, 116],
        'speed_bump': [53, 209, 243],
        'rest': [20, 20, 20]
    }

    thickness_map = {
        'lane': 12,
        'road_line': 3,
        'road_edge': 2,
        'stop_sign': 4,
        'crosswalk': 5,
        'speed_bump': 4,
    }

    all_polylines = map_infos.get("all_polylines", None)
    if all_polylines is None or len(all_polylines) == 0:
        print("No polylines found.")
        return

    # Calculate bounds with margin
    margin = 0
    scale = 4
    x = all_polylines[:, 0]
    y = all_polylines[:, 1]
    x_min, x_max = np.round(x.min() - margin), np.round(x.max() + margin)
    y_min, y_max = np.round(y.min() - margin), np.round(y.max() + margin)
    x_size = int(np.round((x_max - x_min) * scale))
    y_size = int(np.round((y_max - y_min) * scale))

    def draw_map(canvas, cmap):
        for feature_type, color in cmap.items():
            if feature_type == 'rest':
                continue
            thickness = thickness_map.get(feature_type, 1)
            for item in map_infos[feature_type]:
                start, end = item['polyline_index']
                polyline = all_polylines[start:end]
                pts = np.round((polyline[:, :2] - [x_min, y_min]) * scale).astype(int)
                for i in range(len(pts) - 1):
                    cv2.line(canvas, tuple(pts[i]), tuple(pts[i + 1]), color=color, thickness=thickness)
        return canvas

    # Generate visual canvas
    vis_canvas = np.ones((y_size, x_size, 3), dtype=np.uint8) * np.array(color_map['rest'], dtype=np.uint8)
    vis_canvas = draw_map(vis_canvas, color_map)

    # Generate dark canvas
    dark_canvas = np.ones((y_size, x_size, 3), dtype=np.uint8) * np.array(dark_color_map['rest'], dtype=np.uint8)
    dark_canvas = draw_map(dark_canvas, dark_color_map)

    # Save metadata
    meta = np.array([x_min, y_min, scale])
    np.savetxt(meta_path, meta, fmt='%.2f')

    # Create separate filenames
    folder, base = os.path.split(save_path)
    name = os.path.splitext(base)[0]
    vis_path = os.path.join(folder, f"vis_{name}.png")
    dark_path = os.path.join(folder, f"{name}.png")

    # Save images
    cv2.imwrite(vis_path, vis_canvas)
    cv2.imwrite(dark_path, dark_canvas)
    print(f"Saved visual map to {vis_path}")
    print(f"Saved dark map to {dark_path}")
